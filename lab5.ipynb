# %% [markdown]
# Experiment 5: Advanced Convolutional Neural Networks (05_conv_nets_2)
# Aim
#
# To implement an advanced Convolutional Neural Network (CNN) using TensorFlow and Keras with Dropout layers for improved image classification performance.

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
import numpy as np
import random



(X_train, y_train), (X_test, y_test) = datasets.cifar10.load_data()

# Normalize Images
X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

# Different Class Labels
labels = [
    'Plane',
    'Car',
    'Bird',
    'Kitten',
    'Deer',
    'Puppy',
    'Frog',
    'Horse',
    'Boat',
    'Lorry'
]


plt.figure(figsize=(12,12))

for i in range(16):

    plt.subplot(4,4,i+1)

    # Random image index
    index = random.randint(0, 5000)

    plt.imshow(X_train[index])

    plt.title(
        f"Label : {labels[y_train[index][0]]}",
        fontsize=10
    )

    plt.axis('off')

plt.suptitle(
    "Random CIFAR-10 Training Images",
    fontsize=18
)

plt.tight_layout()
plt.show()

# ==============================
# BUILD ADVANCED CNN MODEL
# ==============================
cnn_model = models.Sequential()

# ----- First CNN Block -----
cnn_model.add(layers.Conv2D(
    32,
    (3,3),
    padding='same',
    activation='relu',
    input_shape=(32,32,3)
))

cnn_model.add(layers.BatchNormalization())

cnn_model.add(layers.Conv2D(
    32,
    (3,3),
    padding='same',
    activation='relu'
))

cnn_model.add(layers.MaxPooling2D((2,2)))
cnn_model.add(layers.Dropout(0.3))

# ----- Second CNN Block -----
cnn_model.add(layers.Conv2D(
    64,
    (3,3),
    padding='same',
    activation='relu'
))

cnn_model.add(layers.BatchNormalization())

cnn_model.add(layers.Conv2D(
    64,
    (3,3),
    padding='same',
    activation='relu'
))

cnn_model.add(layers.MaxPooling2D((2,2)))
cnn_model.add(layers.Dropout(0.3))

# ----- Third CNN Block -----
cnn_model.add(layers.Conv2D(
    128,
    (3,3),
    padding='same',
    activation='relu'
))

cnn_model.add(layers.BatchNormalization())

cnn_model.add(layers.MaxPooling2D((2,2)))
cnn_model.add(layers.Dropout(0.4))


cnn_model.add(layers.Flatten())

cnn_model.add(layers.Dense(
    256,
    activation='relu'
))

cnn_model.add(layers.Dropout(0.5))

cnn_model.add(layers.Dense(
    10,
    activation='softmax'
))


cnn_model.summary()


cnn_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)


training = cnn_model.fit(
    X_train,
    y_train,
    epochs=10,
    batch_size=128,
    validation_split=0.2
)


loss, accuracy = cnn_model.evaluate(
    X_test,
    y_test
)

print("\nFinal Test Accuracy :", accuracy)


plt.figure(figsize=(9,5))

plt.plot(
    training.history['accuracy'],
    marker='o',
    label='Train Accuracy'
)

plt.plot(
    training.history['val_accuracy'],
    marker='s',
    label='Validation Accuracy'
)

plt.title("Model Accuracy Graph")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.grid(True)
plt.legend()

plt.show()


plt.figure(figsize=(9,5))

plt.plot(
    training.history['loss'],
    marker='o',
    label='Train Loss'
)

plt.plot(
    training.history['val_loss'],
    marker='s',
    label='Validation Loss'
)

plt.title("Model Loss Graph")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.grid(True)
plt.legend()

plt.show()


plt.figure(figsize=(12,10))

for i in range(9):

    plt.subplot(3,3,i+1)

    img = X_test[i]

    prediction = cnn_model.predict(
        np.expand_dims(img, axis=0),
        verbose=0
    )

    predicted_label = labels[np.argmax(prediction)]

    plt.imshow(img)

    plt.title(
        f"Predicted : {predicted_label}",
        fontsize=10
    )

    plt.axis('off')

plt.suptitle(
    "CNN Prediction Results",
    fontsize=18
)

plt.tight_layout()
plt.show()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_12 (Conv2D)              │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_16 (Conv2D)              │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_6 (Flatten)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 667,434 (2.55 MB)
#  Trainable params: 666,986 (2.54 MB)
#  Non-trainable params: 448 (1.75 KB)
# Epoch 1/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 174s 538ms/step - accuracy: 0.3211 - loss: 1.8891 - val_accuracy: 0.2008 - val_loss: 4.5643
# Epoch 2/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 162s 517ms/step - accuracy: 0.4603 - loss: 1.4776 - val_accuracy: 0.4365 - val_loss: 1.7958
# Epoch 3/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 201s 514ms/step - accuracy: 0.5354 - loss: 1.2912 - val_accuracy: 0.5401 - val_loss: 1.4392
# Epoch 4/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 208s 533ms/step - accuracy: 0.5918 - loss: 1.1564 - val_accuracy: 0.6392 - val_loss: 1.0967
# Epoch 5/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 199s 524ms/step - accuracy: 0.6294 - loss: 1.0543 - val_accuracy: 0.6297 - val_loss: 1.0792
# Epoch 6/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 199s 516ms/step - accuracy: 0.6564 - loss: 0.9798 - val_accuracy: 0.6429 - val_loss: 1.1166
# Epoch 7/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 202s 516ms/step - accuracy: 0.6765 - loss: 0.9244 - val_accuracy: 0.7164 - val_loss: 0.8006
# Epoch 8/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 201s 513ms/step - accuracy: 0.6933 - loss: 0.8820 - val_accuracy: 0.7062 - val_loss: 0.9002
# Epoch 9/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 162s 518ms/step - accuracy: 0.7087 - loss: 0.8375 - val_accuracy: 0.7029 - val_loss: 0.8770
# Epoch 10/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 163s 520ms/step - accuracy: 0.7199 - loss: 0.8062 - val_accuracy: 0.7335 - val_loss: 0.7796
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 34ms/step - accuracy: 0.7283 - loss: 0.7996
#
# Final Test Accuracy : 0.7282999753952026

# %% [markdown]
# Conclusion
#
# Successfully implemented an advanced CNN model using multiple convolution layers and dropout regularization for image classification on the CIFAR-10 dataset.
